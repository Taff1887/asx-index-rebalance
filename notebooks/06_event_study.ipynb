# %% [markdown]
# # 06 — Event study
#
# Measures abnormal returns around the reference, announcement and effective
# dates for historical additions / removals across the three indices.

# %%
import pandas as pd
from asxrebalance.data.announcements import load_labels
from asxrebalance.paths import PROCESSED_RECONCILED_DIR
labels = load_labels(); labels.head()
