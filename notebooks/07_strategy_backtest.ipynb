# %% [markdown]
# # 07 — Strategy backtest vs ASX 200 buy-and-hold
#
# Runs the trading strategy and compares it against a passive ASX 200 ETF.
# Charts are saved to `outputs/figures/` and a one-row summary to
# `outputs/strategy_performance_summary.csv`.

# %%
from asxrebalance.cli import cmd_backtest_strategy
import argparse
args = argparse.Namespace(strategy='announcement-long-short',
                          start='2020-01-01', end='2025-12-31',
                          benchmark='STW.AX')
cmd_backtest_strategy(args)
