# %% [markdown]
# # 05 — Current rebalance forecast
#
# Runs the forecast pipeline for ASX 50/100/200 as of today and writes the
# current_forecast_*.csv outputs plus the workbook `current_forecast_all.xlsx`.

# %%
from asxrebalance.cli import cmd_forecast_all
import argparse
args = argparse.Namespace(asof='2026-06-01', index=None)
cmd_forecast_all(args)
