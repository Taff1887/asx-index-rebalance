# %% [markdown]
# # 04 — ML overlay training
#
# Trains a calibrated classifier per (index, target) on historical rebalance
# announcements. Uses `sklearn.model_selection.TimeSeriesSplit` so the model is
# never trained on data that postdates the rebalance it is being asked to predict.

# %%
from asxrebalance.cli import cmd_train_ml
import argparse
args = argparse.Namespace(index='ASX200', model='logistic')
cmd_train_ml(args)
