# %% [markdown]
# # 03 — Rules-engine backtest
#
# Walks the historical rebalance calendar for ASX 50/100/200, runs the rules engine
# with information that would have been available before each announcement, and
# compares predicted additions / removals against the historical labels.

# %%
from datetime import date
from asxrebalance.cli import cmd_backtest_rules
import argparse
args = argparse.Namespace(index='ASX200', start='2020-01-01', end='2024-12-31')
cmd_backtest_rules(args)
